# %%
print("haha22)
# Out:
#   Cell In[5], line 1
#     print("haha22)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import pyterrier as pt
my_index = pt.terrier.TerrierIndex('my_index.terrier') # [1]
dataset = pt.get_dataset('irds:antique')
my_index.index(dataset.get_corpus_iter())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 my_index = pt.terrier.TerrierIndex('my_index.terrier') # [1]
#       3 dataset = pt.get_dataset('irds:antique')
# ----> 4 my_index.index(dataset.get_corpus_iter())
#
# File ~/Uni/IR/2025IRProject/.venv/lib/python3.13/site-packages/pyterrier/datasets/_irds.py:43, in IRDSDataset.get_corpus_iter(self, verbose, start, count)
#      41 # tqdm support
#      42 if verbose:
# ---> 43     it = pt.tqdm(it, desc=f'{self._irds_id} documents', total=total)
#      45 # rewrite to follow pyterrier std
#      46 def gen():
#
# File ~/Uni/IR/2025IRProject/.venv/lib/python3.13/site-packages/tqdm/std.py:665, in tqdm.__new__(cls, *_, **__)
#     663 def __new__(cls, *_, **__):
#     664     instance = object.__new__(cls)
# --> 665     with cls.get_lock():  # also constructs lock if non-existent
#     666         cls._instances.add(instance)
#     667         # create monitoring thread
#
# File ~/Uni/IR/2025IRProject/.venv/lib/python3.13/site-packages/tqdm/std.py:111, in TqdmDefaultWriteLock.__enter__(self)
#     110 def __enter__(self):
# --> 111     self.acquire()
#
# File ~/Uni/IR/2025IRProject/.venv/lib/python3.13/site-packages/tqdm/std.py:104, in TqdmDefaultWriteLock.acquire(self, *a, **k)
#     102 def acquire(self, *a, **k):
#     103     for lock in self.locks:
# --> 104         lock.acquire(*a, **k)
#
# KeyboardInterrupt:
